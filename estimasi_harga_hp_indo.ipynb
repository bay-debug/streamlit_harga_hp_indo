# %% [markdown]
# # Komoditas (Penjelasan dengan crips-DM)

# %% [markdown]
# # BUSINESS UNDERSTANDING
#    Pada tahap ini membutuhkan pemahaman dalam pengtahuan objek bisnis, dan bagaimana untuk mencocokan tujuan pemodelan untuk tujuan bisnis sehingga model terbaik dapat dibangun.
#
#    > Masalah : Handphone merupakan alat telekomunikasi elektronik bersifat dua arah yang mudah untuk kita bawa kemana-mana dan mempunyai kemampuan untuk bisa mengirim pesan baik berupa suara, gambar dan informasi yang membutukan ruang penyimpanan.
#
#    Karena setiap handphone memiliki penyimpanan internal yang berbeda-beda,setiap Brand Handphone memberikan rekomendasi harga handphone yang berbeda untuk setiap penyimpanan internal.
#
#
#    > Tujuan : Dataset yang di ambil dari kaggle (https://www.kaggle.com/datasets/luthfikun/indonesian-phone-dataset) bertujuan untuk memprediksi harga 1 unit handphone dengan menggunakan metode regresi linier.
#
# # DATA UNDERSTANDING
#    Tahap ini memberikan pondasi analitik untuk sebuah penelitian dengan membuat ringkasan (summary) dan mengindentifikasi potensi masalah dalam data.
#
#    Dari pengumpulan data yang telah diambil mengenai Harga Handphone, terdapat 19 kolom yang berisi 6 kolom integer, 5 kolom float, 2 kolom object dan 6 kolom boolean. Jika menggunakan regresi linear, maka hanya kolom yang berisi float dan int saja yang bisa diolah. Berikut atribut nya :
#
#  0   device                (object)  = Nama ponsel cerdas
#  1   memory                (int64)   = RAM dalam GB
#  2   internal_storage      (int64)   = Penyimpanan Internal dalam GB
#  3   os_price              (int64)   = Harga Resmi
#  4   dual_sim              (bool)    = Dukungan Dual Sim
#  5   esim                  (bool)    = Dukungan E-Sim
#  6   memory_slot           (bool)    = Dukungan Kartu SD
#  7   5g                    (bool)    = Dukungan 5G
#  8   nfc                   (bool)    = Dukungan NFC
#  9   body_length           (float64) = Panjang telepon fisik dalam mm
#  10  body_width            (float64) = Lebar ponsel fisik dalam mm
#  11  body_thickness        (float64) = Ketebalan ponsel fisik dalam mm
#  12  weight                (float64) = Berat telepon fisik dalam gr
#  13  battery               (int64)   = Ukuran baterai dalam mAh
#  14  display_type          (object)  = Tipe tampilan
#  15  display_size          (float64) = Ukuran layar dalam inci
#  16  display_res           (int64)   = Menampilkan resolusi vertikal
#  17  refesh_rate           (int64)   = Kecepatan refresh layar
#  18  display_hdr           (bool)    = Dukungan HDR
#
# # DATA PREPARATION
#    Tahap ini secara garis besar dipakai untuk memperbaiki masalah dalam data, sangat jelas bahwa dalam tahap ini membutuhkan pemikiran yang cukup matang dan usaha yang cukup tinggi untuk memastikan data tepat untuk algoritma yang digunakan dan proses data dapat menuju model berkualitas yang berguna.
#
#    Terdapat 168 data Internal_Storage(Penyimpanan Internal) dengan 19 atribut dengan tipe data yang digunakan yaitu float,int dan atribut data yang di ambil yaitu :
#
#    > internal_storage
#    > memory
#    > os_price
#    > battery
#    > refesh_rate
#    > display_size
#
#
# sedangkan internal_storage sebagai target.
#
# # MODELLING
#    Pada tahap ini dilakukan metode statistika dan Machine Learning untuk penentuan terhadap teknik data mining, alat bantu data mining, dan algoritrma data mining yang akan diterapkan. Jika diperlukan penyesuaian data terhadap teknik data mining tertentu, maka dapat kembali ke tahap data preparation.
#
#    Model yang digunakan untuk menganalisis data statistik ini yaitu regresi linier.
#
# # EVALUATION
#    Setelah di dapatkan beberapa model, sehingga dilakukan penilaian terkait kualitas dan efektisitas-nya. Kemudian lakukan interpretasi terhadap hasil dari data mining yang dihasilkan dalam proses pemodelan pada tahap sebelumnya, dengan tujuan agar model yang ditentukan dapat sesuai dengan tujuan yang ingin dicapai dalam tahap pertama atau tahap business understanding.

# %% [markdown]
# # Deskripsi Library yang digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Memanggil Dataset

# %%
df = pd.read_csv('Indonesian_Phone_Dataset.csv')

# %% [markdown]
# # Deskripsi Dataset

# %%
df.head()
# Out:
#             device  memory  internal_storage  os_price  dual_sim  esim  \
# 0  Apple iPhone 13       4               128     15200      True  True
# 1  Apple iPhone 13       4               512     19500      True  True
# 2  Apple iPhone 14       6               128     16000      True  True
# 3  Apple iPhone 14       6               256     19000      True  True
# 4  Apple iPhone 14       6               512     23000      True  True
#
#    memory_slot    5g   nfc  body_length  body_width  body_thickness  weight  \
# 0        False  True  True        146.7        71.5             7.7   174.0
# 1        False  True  True        146.7        71.5             7.7   174.0
# 2        False  True  True        146.7        71.5             7.8   172.0
# 3        False  True  True        146.7        71.5             7.8   172.0
# 4        False  True  True        146.7        71.5             7.8   172.0
#
#    battery display_type  display_size  display_res  refesh_rate  display_hdr
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   device            168 non-null    object
#  1   memory            168 non-null    int64
#  2   internal_storage  168 non-null    int64
#  3   os_price          168 non-null    int64
#  4   dual_sim          168 non-null    bool
#  5   esim              168 non-null    bool
#  6   memory_slot       168 non-null    bool
#  7   5g                168 non-null    bool
#  8   nfc               168 non-null    bool
#  9   body_length       168 non-null    float64
#  10  body_width        168 non-null    float64
#  11  body_thickness    168 non-null    float64
#  12  weight            157 non-null    float64
#  13  battery           168 non-null    int64
#  14  display_type      168 non-null    object
#  15  display_size      168 non-null    float64
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#            memory  internal_storage      os_price  body_length  body_width  \
# count  168.000000        168.000000    168.000000   168.000000  168.000000
# mean     5.988095        152.761905   5418.273810   162.805952   75.947619
# std      2.928260        131.203149   5935.593034     5.779343    6.256723
# min      2.000000         32.000000    970.000000   138.400000   67.300000
# 25%      4.000000         64.000000   1800.000000   160.500000   74.500000
# 50%      6.000000        128.000000   2700.000000   164.000000   75.600000
# 75%      8.000000        256.000000   6000.000000   164.900000   76.600000
# max     18.000000       1024.000000  31000.000000   173.000000  130.100000
#
#        body_thickness      weight      battery  display_size  display_res  \
# count      168.000000  157.000000   168.000000    168.000000   168.000000
# mean         8.353571  191.284713  4854.059524      6.546607   968.291667
# ...

# %% [markdown]
# # Visualisasi Data

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14784\2675538813.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # Harga Perangkat Berdasarkan Penyimpanan Internal

# %%
print(df.columns)
# Out:
# Index(['device', 'memory', 'internal_storage', 'os_price', 'dual_sim', 'esim',
#        'memory_slot', '5g', 'nfc', 'body_length', 'body_width',
#        'body_thickness', 'weight', 'battery', 'display_type', 'display_size',
#        'display_res', 'refesh_rate', 'display_hdr'],
#       dtype='object')

# %%
internal = df.groupby('internal_storage').count()[['os_price']].sort_values(by='os_price',ascending=True).reset_index()
internal = internal.rename(columns={'os_price':'numberOfos_price'})

# %%
fig = plt.figure(figsize=(15,5))
sns.barplot(x=internal['internal_storage'], y=internal['numberOfos_price'], color='royalblue')
plt.xticks(rotation=60)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '32'),
#   Text(1, 0, '64'),
#   Text(2, 0, '128'),
#   Text(3, 0, '256'),
#   Text(4, 0, '512'),
#   Text(5, 0, '1024')])

# %% [markdown]
# # Distribusi Memori

# %%
plt.figure(figsize=(15,5))
sns.distplot(df['memory'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14784\4055109017.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['memory'])
# <Axes: xlabel='memory', ylabel='Density'>

# %% [markdown]
# # Distribusi Penyimpanan Internal

# %%
plt.figure(figsize=(15,5))
sns.distplot(df['internal_storage'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14784\2670064402.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['internal_storage'])
# <Axes: xlabel='internal_storage', ylabel='Density'>

# %% [markdown]
# # Distribusi Baterai

# %%
plt.figure(figsize=(15,5))
sns.distplot(df['battery'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14784\2372444312.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['battery'])
# <Axes: xlabel='battery', ylabel='Density'>

# %% [markdown]
# # Distribusi Penyegaran Layar

# %%
plt.figure(figsize=(15,5))
sns.distplot(df['refesh_rate'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14784\415550478.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['refesh_rate'])
# <Axes: xlabel='refesh_rate', ylabel='Density'>

# %% [markdown]
# # Distibusi Ukuran Layar

# %%
plt.figure(figsize=(15,5))
sns.distplot(df['display_size'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14784\3004896359.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['display_size'])
# <Axes: xlabel='display_size', ylabel='Density'>

# %% [markdown]
# # seleksi fitur

# %%
features = ['internal_storage','memory','refesh_rate','battery','display_size']
x = df[features]
y = df['os_price']
x.shape, y.shape
# Out:
# ((168, 5), (168,))

# %% [markdown]
# # split data training dan data testing

# %%
from sklearn.model_selection import train_test_split
x_train, X_test, y_train, y_test = train_test_split(x,y,random_state=70)
y_test.shape
# Out:
# (42,)

# %% [markdown]
# # membuat model regresi linier

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(X_test)

# %%
score = lr.score(X_test, y_test)
print('akurasi model regresi linier = ', score)
# Out:
# akurasi model regresi linier =  0.7357666789663027

# %% [markdown]
# # membuat inputan model regresi linier

# %%
input_data = np.array([[128,8,120,6000,61]])

prediction = lr.predict(input_data)
print('Estimasi Harga Handphone Indonesia :', prediction)
# Out:
# Estimasi Harga Handphone Indonesia : [163061.86547673]
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # save model

# %%
import pickle

filename = 'estimasi_harga_hp_indo.sav'
pickle.dump(lr,open(filename,'wb'))
